# %% [markdown]
# ### IMDB Sentiment Analysis
# This model uses IMDB  dataset from Stanford NLP via Hugging Face (stanfordnlp/imdb)
#
# #### Dataset Summary
# Large Movie Review Dataset. This is a dataset for binary sentiment classification containing substantially more data than previous benchmark datasets. It includes 25,000 highly polar movie reviews for training, and 25,000 for testing.
#
# Data values:
# - text: a string feature.
# - label: a classification label, with possible values including neg (0), pos (1).

# %%
import torch
from datasets import load_dataset
from transformers import pipeline, AutoModel, AutoTokenizer, BertTokenizer, Trainer, TrainingArguments    
import torch.nn.functional as f

from transformers import pipeline
from transformers.pipelines.pt_utils import KeyDataset
from tqdm.auto import tqdm

import re
import numpy as np
import pandas as pd 

import pyarrow as pa

# %%
import nltk
#nltk.download('punkt') # one time execution
# nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
from nltk.tokenize import word_tokenize

# %%
# Loading IMDB Dataset 
dataset = load_dataset("imdb", split='train').to_pandas()
#dataset

# Splitting Text and Labels 
reviews = dataset['text']
labels = dataset['label']

# %%
# Preprocessing the data 
# Remove <br /><br /> tags
# Remove ***** 
# Remove stop words 

def clean_text(txt): 
    try: 
        word_tokens = word_tokenize(txt)
        filtered_word = [w for w in word_tokens if w.lower() not in stop_words] 
        filtered_word = [w for w in filtered_word if w.lower() not in ["<br /><br />", "*****", "* * * *", '<', 'br', '/', '>', '<', 'br', '/', '>']] 
        filtered_word = [w + " " for w in filtered_word]
        return "".join(filtered_word)
    except:
        return txt
    
    txt["text"] = "Review: " + txt["text"]



# a = 'I rented I AM CURIOUS-YELLOW from my video store because of all the controversy that surrounded it when it was first released in 1967. I also heard that at first it was seized by U.S. customs if it ever tried to enter this country, therefore being a fan of films considered "controversial" I really had to see this for myself.<br /><br />The plot is centered around a young Swedish drama student named Lena who wants to learn everything she can about life. In particular she wants to focus her attentions to making some sort of documentary on what the average Swede thought about certain political issues such as the Vietnam War and race issues in the United States. In between asking politicians and ordinary denizens of Stockholm about their opinions on politics, she has sex with her drama teacher, classmates, and married men.<br /><br />What kills me about I AM CURIOUS-YELLOW is that 40 years ago, this was considered pornographic. Really, the sex and nudity scenes are few and far between, even then it\'s not shot like some cheaply made porno. While my countrymen mind find it shocking, in reality sex and nudity are a major staple in Swedish cinema. Even Ingmar Bergman, arguably their answer to good old boy John Ford, had sex scenes in his films.<br /><br />I do commend the filmmakers for the fact that any sex shown in the film is shown for artistic purposes rather than just to shock people and make money to be shown in pornographic theaters in America. I AM CURIOUS-YELLOW is a good film for anyone wanting to study the meat and potatoes (no pun intended) of Swedish cinema. But really, this film doesn\'t have much of a plot.'

# clean_text(a)

dataset2 = dataset
dataset2['cleaned_text'] = dataset2['text'].apply(clean_text)

dataset2

# %%
from datasets import Dataset
hg_dataset = Dataset(pa.Table.from_pandas(dataset2))

# %%
hg_dataset
# Out:
# Dataset({
#     features: ['text', 'label', 'cleaned_text'],
#     num_rows: 25000
# })

# %%
################################################################
########  Using pipeline function for Sentiment Analysis ########
classifier = pipeline('sentiment-analysis')
classifier_results_dict = {}
counter = 0
results = []

for out in classifier(KeyDataset(hg_dataset, "cleaned_text"), batch_size=8, truncation="only_first"):    
    print(out)
    results.append(out)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# {'label': 'NEGATIVE', 'score': 0.9922564029693604}
# {'label': 'NEGATIVE', 'score': 0.9993064403533936}
# {'label': 'NEGATIVE', 'score': 0.6541439890861511}
# {'label': 'NEGATIVE', 'score': 0.9501397609710693}
# {'label': 'NEGATIVE', 'score': 0.9966205358505249}
# {'label': 'NEGATIVE', 'score': 0.9996757507324219}
# {'label': 'NEGATIVE', 'score': 0.9996438026428223}
# {'label': 'NEGATIVE', 'score': 0.9964983463287354}
# {'label': 'NEGATIVE', 'score': 0.9957259893417358}
# {'label': 'NEGATIVE', 'score': 0.9967143535614014}
# {'label': 'NEGATIVE', 'score': 0.8005483746528625}
# {'label': 'NEGATIVE', 'score': 0.9992138147354126}
# {'label': 'NEGATIVE', 'score': 0.9994953870773315}
# {'label': 'NEGATIVE', 'score': 0.9910323023796082}
# {'label': 'NEGATIVE', 'score': 0.9948911666870117}
# {'label': 'NEGATIVE', 'score': 0.999721109867096}
# {'label': 'NEGATIVE', 'score': 0.9975783228874207}
# {'label': 'NEGATIVE', 'score': 0.999669075012207}
# {'label': 'NEGATIVE', 'score': 0.9996323585510254}
# {'label': 'NEGATIVE', 'score': 0.9995846152305603}
# {'label': 'NEGATIVE', 'score': 0.989035427570343}
# {'label': 'NEGATIVE', 'score': 0.9638575911521912}
# {'label': 'NEGATIVE', 'score': 0.9850842356681824}
# {'label': 'NEGATIVE', 'score': 0.7107500433921814}
# {'label': 'NEGATIVE', 'score': 0.9994514584541321}
# {'label': 'NEGATIVE', 'score': 0.998837411403656}
# {'label': 'NEGATIVE', 'score': 0.9993552565574646}
# {'label': 'NEGATIVE', 'score': 0.8406557440757751}
# {'label': 'NEGATIVE', 'score': 0.9984921216964722}
# {'label': 'NEGATIVE', 'score': 0.9949042797088623}
# {'label': 'NEGATIVE', 'score': 0.9997490048408508}
# {'label': 'NEGATIVE', 'score': 0.9968819618225098}
# {'label': 'NEGATIVE', 'score': 0.8467011451721191}
# {'label': 'NEGATIVE', 'score': 0.9997790455818176}
# {'label': 'NEGATIVE', 'score': 0.9995757937431335}
# {'label': 'NEGATIVE', 'score': 0.9207767844200134}
# {'label': 'NEGATIVE', 'score': 0.9995933175086975}
# {'label': 'NEGATIVE', 'score': 0.9989995360374451}
# {'label': 'NEGATIVE', 'score': 0.985169529914856}
# {'label': 'POSITIVE', 'score': 0.9790312647819519}
# {'label': 'NEGATIVE', 'score': 0.9485636949539185}
# {'label': 'NEGATIVE', 'score': 0.9872164130210876}
# {'label': 'NEGATIVE', 'score': 0.9994258880615234}
# {'label': 'POSITIVE', 'score': 0.5356824398040771}
# {'label': 'NEGATIVE', 'score': 0.9949415326118469}
# {'label': 'NEGATIVE', 'score': 0.999739944934845}
# {'label': 'NEGATIVE', 'score': 0.9950321912765503}
# {'label': 'NEGATIVE', 'score': 0.9993923902511597}
# {'label': 'NEGATIVE', 'score': 0.9986855387687683}
# {'label': 'NEGATIVE', 'score': 0.9996564388275146}
# {'label': 'NEGATIVE', 'score': 0.9745654463768005}
# {'label': 'NEGATIVE', 'score': 0.9987874627113342}
# {'label': 'NEGATIVE', 'score': 0.9970000386238098}
# {'label': 'POSITIVE', 'score': 0.9984583854675293}
# {'label': 'NEGATIVE', 'score': 0.9933909177780151}
# {'label': 'NEGATIVE', 'score': 0.9985255599021912}
# {'label': 'NEGATIVE', 'score': 0.9989995360374451}
# {'label': 'NEGATIVE', 'score': 0.9977198243141174}
# {'label': 'NEGATIVE', 'score': 0.9981637597084045}
# {'label': 'NEGATIVE', 'score': 0.9997528195381165}
# {'label': 'NEGATIVE', 'score': 0.9329718351364136}
# {'label': 'POSITIVE', 'score': 0.9858723282814026}
# {'label': 'NEGATIVE', 'score': 0.6715713143348694}
# {'label': 'NEGATIVE', 'score': 0.9987665414810181}
# {'label': 'NEGATIVE', 'score': 0.7014269828796387}
# {'label': 'NEGATIVE', 'score': 0.9985668063163757}
# {'label': 'NEGATIVE', 'score': 0.9986894726753235}
# {'label': 'NEGATIVE', 'score': 0.9967966675758362}
# {'label': 'NEGATIVE', 'score': 0.9976946711540222}
# {'label': 'NEGATIVE', 'score': 0.9747401475906372}
# {'label': 'NEGATIVE', 'score': 0.9973459243774414}
# {'label': 'NEGATIVE', 'score': 0.9788230061531067}
# {'label': 'NEGATIVE', 'score': 0.9998130202293396}
# {'label': 'NEGATIVE', 'score': 0.9756442904472351}
# {'label': 'POSITIVE', 'score': 0.9763686656951904}
# {'label': 'NEGATIVE', 'score': 0.9981012940406799}
# {'label': 'NEGATIVE', 'score': 0.9994521737098694}
# {'label': 'NEGATIVE', 'score': 0.9477766156196594}
# {'label': 'NEGATIVE', 'score': 0.9984409213066101}
# {'label': 'POSITIVE', 'score': 0.9887371063232422}
# {'label': 'NEGATIVE', 'score': 0.9956973791122437}
# {'label': 'NEGATIVE', 'score': 0.966978132724762}
# {'label': 'NEGATIVE', 'score': 0.9992069602012634}
# {'label': 'NEGATIVE', 'score': 0.999091386795044}
# {'label': 'NEGATIVE', 'score': 0.9832109212875366}
# {'label': 'NEGATIVE', 'score': 0.996563732624054}
# {'label': 'NEGATIVE', 'score': 0.9685901999473572}
# {'label': 'NEGATIVE', 'score': 0.9991443157196045}
# {'label': 'NEGATIVE', 'score': 0.9991984963417053}
# {'label': 'POSITIVE', 'score': 0.9660415053367615}
# {'label': 'NEGATIVE', 'score': 0.9980983138084412}
# {'label': 'NEGATIVE', 'score': 0.9866189360618591}
# {'label': 'POSITIVE', 'score': 0.5478882193565369}
# {'label': 'NEGATIVE', 'score': 0.9997953772544861}
# {'label': 'NEGATIVE', 'score': 0.9994198083877563}
# {'label': 'NEGATIVE', 'score': 0.9920424818992615}
# {'label': 'NEGATIVE', 'score': 0.9992941617965698}
# {'label': 'NEGATIVE', 'score': 0.9890761375427246}
# {'label': 'NEGATIVE', 'score': 0.971616804599762}
# {'label': 'NEGATIVE', 'score': 0.9993600249290466}
# {'label': 'NEGATIVE', 'score': 0.9997650980949402}
# {'label': 'NEGATIVE', 'score': 0.9996280670166016}
# {'label': 'NEGATIVE', 'score': 0.9853307008743286}
# {'label': 'NEGATIVE', 'score': 0.9989853501319885}
# {'label': 'NEGATIVE', 'score': 0.9989526271820068}
# {'label': 'NEGATIVE', 'score': 0.9991570711135864}
# {'label': 'NEGATIVE', 'score': 0.9988849759101868}
# {'label': 'NEGATIVE', 'score': 0.9996312856674194}
# {'label': 'NEGATIVE', 'score': 0.9767657518386841}
# {'label': 'NEGATIVE', 'score': 0.9989424347877502}
# {'label': 'NEGATIVE', 'score': 0.9846551418304443}
# {'label': 'NEGATIVE', 'score': 0.9654620289802551}
# {'label': 'NEGATIVE', 'score': 0.9995365142822266}
# {'label': 'NEGATIVE', 'score': 0.9477768540382385}
# {'label': 'NEGATIVE', 'score': 0.9996556043624878}
# {'label': 'NEGATIVE', 'score': 0.9991055130958557}
# {'label': 'NEGATIVE', 'score': 0.9991768002510071}
# {'label': 'NEGATIVE', 'score': 0.9981791973114014}
# {'label': 'NEGATIVE', 'score': 0.9992741942405701}
# {'label': 'NEGATIVE', 'score': 0.8351144790649414}
# {'label': 'NEGATIVE', 'score': 0.7253943085670471}
# {'label': 'NEGATIVE', 'score': 0.9990909099578857}
# {'label': 'NEGATIVE', 'score': 0.9921844601631165}
# {'label': 'NEGATIVE', 'score': 0.9263851046562195}
# {'label': 'POSITIVE', 'score': 0.986928403377533}
# {'label': 'NEGATIVE', 'score': 0.9994246959686279}
# {'label': 'NEGATIVE', 'score': 0.99910968542099}
# {'label': 'NEGATIVE', 'score': 0.9872326850891113}
# {'label': 'NEGATIVE', 'score': 0.9973835349082947}
# {'label': 'NEGATIVE', 'score': 0.9984003901481628}
# {'label': 'NEGATIVE', 'score': 0.981657862663269}
# {'label': 'NEGATIVE', 'score': 0.9973199963569641}
# {'label': 'NEGATIVE', 'score': 0.9608398079872131}
# {'label': 'NEGATIVE', 'score': 0.9986912608146667}
# {'label': 'NEGATIVE', 'score': 0.9831711649894714}
# {'label': 'NEGATIVE', 'score': 0.7044047713279724}
# {'label': 'NEGATIVE', 'score': 0.9987989664077759}
# {'label': 'NEGATIVE', 'score': 0.9943702816963196}
# {'label': 'POSITIVE', 'score': 0.8238499164581299}
# {'label': 'NEGATIVE', 'score': 0.9986878037452698}
# {'label': 'NEGATIVE', 'score': 0.9943558573722839}
# {'label': 'NEGATIVE', 'score': 0.9996365308761597}
# {'label': 'NEGATIVE', 'score': 0.964177131652832}
# {'label': 'NEGATIVE', 'score': 0.9984069466590881}
# {'label': 'NEGATIVE', 'score': 0.9889955520629883}
# {'label': 'POSITIVE', 'score': 0.9939123392105103}
# {'label': 'POSITIVE', 'score': 0.8540711402893066}
# {'label': 'NEGATIVE', 'score': 0.9926233291625977}
# {'label': 'POSITIVE', 'score': 0.9838941693305969}
# {'label': 'NEGATIVE', 'score': 0.9994980096817017}
# {'label': 'NEGATIVE', 'score': 0.9991866946220398}
# {'label': 'NEGATIVE', 'score': 0.9992249011993408}
# {'label': 'NEGATIVE', 'score': 0.9991297125816345}
# {'label': 'NEGATIVE', 'score': 0.9985097050666809}
# {'label': 'NEGATIVE', 'score': 0.9980993866920471}
# {'label': 'POSITIVE', 'score': 0.9507557153701782}
# {'label': 'NEGATIVE', 'score': 0.9957171082496643}
# {'label': 'NEGATIVE', 'score': 0.9950396418571472}
# {'label': 'NEGATIVE', 'score': 0.9997351765632629}
# {'label': 'NEGATIVE', 'score': 0.8380172252655029}
# {'label': 'NEGATIVE', 'score': 0.9993218183517456}
# {'label': 'NEGATIVE', 'score': 0.9991598129272461}
# {'label': 'NEGATIVE', 'score': 0.9803155064582825}
# {'label': 'POSITIVE', 'score': 0.9518604278564453}
# {'label': 'NEGATIVE', 'score': 0.95404452085495}
# {'label': 'NEGATIVE', 'score': 0.9954560995101929}
# {'label': 'NEGATIVE', 'score': 0.9976014494895935}
# {'label': 'POSITIVE', 'score': 0.9783830046653748}
# {'label': 'POSITIVE', 'score': 0.9783830046653748}
# {'label': 'NEGATIVE', 'score': 0.99846351146698}
# {'label': 'NEGATIVE', 'score': 0.9977515339851379}
# {'label': 'NEGATIVE', 'score': 0.9975583553314209}
# {'label': 'NEGATIVE', 'score': 0.9679056406021118}
# {'label': 'NEGATIVE', 'score': 0.8019663095474243}
# {'label': 'NEGATIVE', 'score': 0.9927183389663696}
# {'label': 'NEGATIVE', 'score': 0.9996649026870728}
# {'label': 'NEGATIVE', 'score': 0.9988860487937927}
# {'label': 'NEGATIVE', 'score': 0.9987612962722778}
# {'label': 'NEGATIVE', 'score': 0.9981593489646912}
# {'label': 'NEGATIVE', 'score': 0.998314619064331}
# {'label': 'NEGATIVE', 'score': 0.9957351684570312}
# {'label': 'NEGATIVE', 'score': 0.9993065595626831}
# {'label': 'POSITIVE', 'score': 0.9963082671165466}
# {'label': 'NEGATIVE', 'score': 0.9956142902374268}
# {'label': 'NEGATIVE', 'score': 0.9991322159767151}
# {'label': 'NEGATIVE', 'score': 0.9991242289543152}
# {'label': 'NEGATIVE', 'score': 0.9994433522224426}
# {'label': 'NEGATIVE', 'score': 0.9990671277046204}
# {'label': 'POSITIVE', 'score': 0.9608110785484314}
# {'label': 'POSITIVE', 'score': 0.9469692707061768}
# {'label': 'POSITIVE', 'score': 0.928658664226532}
# {'label': 'NEGATIVE', 'score': 0.9949427247047424}
# {'label': 'POSITIVE', 'score': 0.9945639371871948}
# {'label': 'NEGATIVE', 'score': 0.9885464906692505}
# {'label': 'NEGATIVE', 'score': 0.9981416463851929}
# {'label': 'NEGATIVE', 'score': 0.9987807869911194}
# {'label': 'NEGATIVE', 'score': 0.9996691942214966}
# {'label': 'NEGATIVE', 'score': 0.9959284663200378}
# {'label': 'POSITIVE', 'score': 0.9825237393379211}
# {'label': 'POSITIVE', 'score': 0.9786832332611084}
# {'label': 'POSITIVE', 'score': 0.9995203018188477}
# {'label': 'NEGATIVE', 'score': 0.9971861243247986}
# {'label': 'NEGATIVE', 'score': 0.9991781115531921}
# {'label': 'NEGATIVE', 'score': 0.976504385471344}
# {'label': 'NEGATIVE', 'score': 0.9858260750770569}
# {'label': 'NEGATIVE', 'score': 0.998913049697876}
# {'label': 'NEGATIVE', 'score': 0.9979745745658875}
# {'label': 'NEGATIVE', 'score': 0.995429515838623}
# {'label': 'NEGATIVE', 'score': 0.9988547563552856}
# {'label': 'NEGATIVE', 'score': 0.999285876750946}
# {'label': 'POSITIVE', 'score': 0.9990121126174927}
# {'label': 'POSITIVE', 'score': 0.6129701733589172}
# {'label': 'NEGATIVE', 'score': 0.9989761114120483}
# {'label': 'NEGATIVE', 'score': 0.9969858527183533}
# {'label': 'NEGATIVE', 'score': 0.9994565844535828}
# {'label': 'NEGATIVE', 'score': 0.9985553622245789}
# {'label': 'NEGATIVE', 'score': 0.9990608096122742}
# {'label': 'NEGATIVE', 'score': 0.9936648607254028}
# {'label': 'POSITIVE', 'score': 0.5504730343818665}
# {'label': 'POSITIVE', 'score': 0.673759400844574}
# {'label': 'NEGATIVE', 'score': 0.9925669431686401}
# {'label': 'NEGATIVE', 'score': 0.9988073110580444}
# {'label': 'NEGATIVE', 'score': 0.9995637536048889}
# {'label': 'NEGATIVE', 'score': 0.998026430606842}
# {'label': 'POSITIVE', 'score': 0.9775698184967041}
# {'label': 'NEGATIVE', 'score': 0.9945047497749329}
# {'label': 'NEGATIVE', 'score': 0.725568950176239}
# {'label': 'NEGATIVE', 'score': 0.9995452761650085}
# {'label': 'NEGATIVE', 'score': 0.9921954870223999}
# {'label': 'NEGATIVE', 'score': 0.9944979548454285}
# {'label': 'NEGATIVE', 'score': 0.9938589930534363}
# {'label': 'POSITIVE', 'score': 0.9565921425819397}
# {'label': 'NEGATIVE', 'score': 0.9993113279342651}
# {'label': 'NEGATIVE', 'score': 0.9831346273422241}
# {'label': 'NEGATIVE', 'score': 0.9985525012016296}
# {'label': 'NEGATIVE', 'score': 0.9951267242431641}
# {'label': 'NEGATIVE', 'score': 0.999025821685791}
# {'label': 'NEGATIVE', 'score': 0.9975302815437317}
# {'label': 'NEGATIVE', 'score': 0.9982731342315674}
# {'label': 'NEGATIVE', 'score': 0.9995691180229187}
# {'label': 'NEGATIVE', 'score': 0.9994788765907288}
# {'label': 'POSITIVE', 'score': 0.8413946032524109}
# {'label': 'NEGATIVE', 'score': 0.984271228313446}
# {'label': 'NEGATIVE', 'score': 0.999040424823761}
# {'label': 'NEGATIVE', 'score': 0.9437397122383118}
# {'label': 'NEGATIVE', 'score': 0.8712116479873657}
# {'label': 'NEGATIVE', 'score': 0.9991965889930725}
# {'label': 'NEGATIVE', 'score': 0.995594322681427}
# {'label': 'NEGATIVE', 'score': 0.9972968697547913}
# {'label': 'NEGATIVE', 'score': 0.9982700347900391}
# {'label': 'NEGATIVE', 'score': 0.9990986585617065}
# {'label': 'NEGATIVE', 'score': 0.9987068176269531}
# {'label': 'POSITIVE', 'score': 0.9980531930923462}
# {'label': 'NEGATIVE', 'score': 0.9988365769386292}
# {'label': 'NEGATIVE', 'score': 0.9934849143028259}
# {'label': 'POSITIVE', 'score': 0.9859058856964111}
# {'label': 'NEGATIVE', 'score': 0.9867801070213318}
# {'label': 'NEGATIVE', 'score': 0.9861778020858765}
# {'label': 'NEGATIVE', 'score': 0.9963886737823486}
# {'label': 'NEGATIVE', 'score': 0.9692187905311584}
# {'label': 'POSITIVE', 'score': 0.9947260022163391}
# {'label': 'NEGATIVE', 'score': 0.9897504448890686}
# {'label': 'NEGATIVE', 'score': 0.9989884495735168}
# {'label': 'NEGATIVE', 'score': 0.5436202883720398}
# {'label': 'NEGATIVE', 'score': 0.998250424861908}
# {'label': 'NEGATIVE', 'score': 0.9971019625663757}
# {'label': 'NEGATIVE', 'score': 0.9979408383369446}
# {'label': 'NEGATIVE', 'score': 0.9822856187820435}
# {'label': 'NEGATIVE', 'score': 0.999000608921051}
# {'label': 'NEGATIVE', 'score': 0.9997945427894592}
# {'label': 'NEGATIVE', 'score': 0.9994156360626221}
# {'label': 'NEGATIVE', 'score': 0.9883434772491455}
# {'label': 'NEGATIVE', 'score': 0.9906162619590759}
# {'label': 'NEGATIVE', 'score': 0.9982452392578125}
# {'label': 'NEGATIVE', 'score': 0.999729573726654}
# {'label': 'NEGATIVE', 'score': 0.9986722469329834}
# {'label': 'NEGATIVE', 'score': 0.9989925026893616}
# {'label': 'NEGATIVE', 'score': 0.9993500113487244}
# {'label': 'NEGATIVE', 'score': 0.990149974822998}
# {'label': 'NEGATIVE', 'score': 0.9994193315505981}
# {'label': 'NEGATIVE', 'score': 0.9024484157562256}
# {'label': 'NEGATIVE', 'score': 0.9540208578109741}
# {'label': 'NEGATIVE', 'score': 0.9952964186668396}
# {'label': 'NEGATIVE', 'score': 0.9585011005401611}
# {'label': 'POSITIVE', 'score': 0.810298502445221}
# {'label': 'POSITIVE', 'score': 0.60529625415802}
# {'label': 'NEGATIVE', 'score': 0.9985659718513489}
# {'label': 'NEGATIVE', 'score': 0.9990118741989136}
# {'label': 'NEGATIVE', 'score': 0.9792485237121582}
# {'label': 'POSITIVE', 'score': 0.9581437706947327}
# {'label': 'NEGATIVE', 'score': 0.9995519518852234}
# {'label': 'NEGATIVE', 'score': 0.9995644688606262}
# {'label': 'NEGATIVE', 'score': 0.9959790706634521}
# {'label': 'POSITIVE', 'score': 0.99623703956604}
# {'label': 'NEGATIVE', 'score': 0.9978252649307251}
# {'label': 'NEGATIVE', 'score': 0.9967353940010071}
# {'label': 'NEGATIVE', 'score': 0.9992921352386475}
# {'label': 'NEGATIVE', 'score': 0.9996788501739502}
# {'label': 'NEGATIVE', 'score': 0.998346209526062}
# {'label': 'NEGATIVE', 'score': 0.9944013953208923}
# {'label': 'NEGATIVE', 'score': 0.97782963514328}
# {'label': 'NEGATIVE', 'score': 0.9979202151298523}
# {'label': 'POSITIVE', 'score': 0.9600474834442139}
# {'label': 'NEGATIVE', 'score': 0.9977573752403259}
# {'label': 'NEGATIVE', 'score': 0.9398245811462402}
# {'label': 'NEGATIVE', 'score': 0.9997149109840393}
# {'label': 'NEGATIVE', 'score': 0.9987334609031677}
# {'label': 'NEGATIVE', 'score': 0.9992570281028748}
# {'label': 'NEGATIVE', 'score': 0.9990403056144714}
# {'label': 'NEGATIVE', 'score': 0.9996423721313477}
# {'label': 'NEGATIVE', 'score': 0.999174177646637}
# {'label': 'NEGATIVE', 'score': 0.999182403087616}
# {'label': 'NEGATIVE', 'score': 0.9991876482963562}
# {'label': 'NEGATIVE', 'score': 0.9428160786628723}
# {'label': 'NEGATIVE', 'score': 0.9994620680809021}
# {'label': 'NEGATIVE', 'score': 0.9997559189796448}
# {'label': 'NEGATIVE', 'score': 0.9881161451339722}
# {'label': 'NEGATIVE', 'score': 0.9908944368362427}
# {'label': 'NEGATIVE', 'score': 0.9994450211524963}
# {'label': 'NEGATIVE', 'score': 0.9994997978210449}
# {'label': 'NEGATIVE', 'score': 0.9899646639823914}
# {'label': 'NEGATIVE', 'score': 0.9941788911819458}
# {'label': 'NEGATIVE', 'score': 0.9996907711029053}
# {'label': 'NEGATIVE', 'score': 0.9997432827949524}
# {'label': 'NEGATIVE', 'score': 0.9984431862831116}
# {'label': 'NEGATIVE', 'score': 0.9970908164978027}
# {'label': 'NEGATIVE', 'score': 0.9993215799331665}
# {'label': 'NEGATIVE', 'score': 0.9997859597206116}
# {'label': 'NEGATIVE', 'score': 0.998783528804779}
# {'label': 'POSITIVE', 'score': 0.8791680335998535}
# {'label': 'NEGATIVE', 'score': 0.9981741905212402}
# {'label': 'NEGATIVE', 'score': 0.9993392825126648}
# {'label': 'NEGATIVE', 'score': 0.9850028157234192}
# {'label': 'POSITIVE', 'score': 0.938612163066864}
# {'label': 'NEGATIVE', 'score': 0.9971551895141602}
# {'label': 'NEGATIVE', 'score': 0.9960585832595825}
# {'label': 'POSITIVE', 'score': 0.870825469493866}
# {'label': 'NEGATIVE', 'score': 0.9971227049827576}
# {'label': 'NEGATIVE', 'score': 0.9995156526565552}
# {'label': 'POSITIVE', 'score': 0.9810925126075745}
# {'label': 'NEGATIVE', 'score': 0.9965984225273132}
# {'label': 'NEGATIVE', 'score': 0.9526845216751099}
# {'label': 'NEGATIVE', 'score': 0.998761773109436}
# {'label': 'NEGATIVE', 'score': 0.9976632595062256}
# {'label': 'NEGATIVE', 'score': 0.9989994168281555}
# {'label': 'NEGATIVE', 'score': 0.9766008853912354}
# {'label': 'NEGATIVE', 'score': 0.9947570562362671}
# {'label': 'NEGATIVE', 'score': 0.9954491257667542}
# {'label': 'NEGATIVE', 'score': 0.9440301060676575}
# {'label': 'NEGATIVE', 'score': 0.9990915060043335}
# {'label': 'NEGATIVE', 'score': 0.9991289973258972}
# {'label': 'NEGATIVE', 'score': 0.9964190721511841}
# {'label': 'NEGATIVE', 'score': 0.9991876482963562}
# {'label': 'NEGATIVE', 'score': 0.9992666840553284}
# {'label': 'NEGATIVE', 'score': 0.9981971383094788}
# {'label': 'NEGATIVE', 'score': 0.99741530418396}
# {'label': 'NEGATIVE', 'score': 0.9997469782829285}
# {'label': 'NEGATIVE', 'score': 0.9989756345748901}
# {'label': 'NEGATIVE', 'score': 0.9988850951194763}
# {'label': 'NEGATIVE', 'score': 0.99965500831604}
# {'label': 'NEGATIVE', 'score': 0.9992486834526062}
# {'label': 'NEGATIVE', 'score': 0.9988237023353577}
# {'label': 'NEGATIVE', 'score': 0.7803502678871155}
# {'label': 'NEGATIVE', 'score': 0.9988263249397278}
# {'label': 'POSITIVE', 'score': 0.8462592959403992}
# {'label': 'NEGATIVE', 'score': 0.8805158138275146}
# {'label': 'NEGATIVE', 'score': 0.9892174005508423}
# {'label': 'NEGATIVE', 'score': 0.9683927297592163}
# {'label': 'NEGATIVE', 'score': 0.9983258843421936}
# {'label': 'NEGATIVE', 'score': 0.998826801776886}
# {'label': 'NEGATIVE', 'score': 0.9983426332473755}
# {'label': 'NEGATIVE', 'score': 0.9986293315887451}
# {'label': 'POSITIVE', 'score': 0.6363375782966614}
# {'label': 'NEGATIVE', 'score': 0.9979887008666992}
# {'label': 'NEGATIVE', 'score': 0.9963047504425049}
# {'label': 'NEGATIVE', 'score': 0.9972279667854309}
# {'label': 'NEGATIVE', 'score': 0.9984810948371887}
# {'label': 'POSITIVE', 'score': 0.7261638641357422}
# {'label': 'POSITIVE', 'score': 0.9992275238037109}
# {'label': 'NEGATIVE', 'score': 0.8724713921546936}
# {'label': 'NEGATIVE', 'score': 0.99601811170578}
# {'label': 'NEGATIVE', 'score': 0.998566210269928}
# {'label': 'NEGATIVE', 'score': 0.9914268255233765}
# {'label': 'NEGATIVE', 'score': 0.9943390488624573}
# {'label': 'NEGATIVE', 'score': 0.7050270438194275}
# {'label': 'NEGATIVE', 'score': 0.999810516834259}
# {'label': 'NEGATIVE', 'score': 0.9994813799858093}
# {'label': 'POSITIVE', 'score': 0.975892961025238}
# {'label': 'NEGATIVE', 'score': 0.8752719163894653}
# {'label': 'NEGATIVE', 'score': 0.9984763264656067}
# {'label': 'NEGATIVE', 'score': 0.9955299496650696}
# {'label': 'NEGATIVE', 'score': 0.9958038926124573}
# {'label': 'NEGATIVE', 'score': 0.9562841653823853}
# {'label': 'NEGATIVE', 'score': 0.9859777688980103}
# {'label': 'NEGATIVE', 'score': 0.937498927116394}
# {'label': 'NEGATIVE', 'score': 0.9991752505302429}
# {'label': 'NEGATIVE', 'score': 0.997512698173523}
# {'label': 'NEGATIVE', 'score': 0.687738835811615}
# {'label': 'NEGATIVE', 'score': 0.9988178610801697}
# {'label': 'NEGATIVE', 'score': 0.9997357726097107}
# {'label': 'NEGATIVE', 'score': 0.9996486902236938}
# {'label': 'NEGATIVE', 'score': 0.9992042183876038}
# {'label': 'NEGATIVE', 'score': 0.9994545578956604}
# {'label': 'NEGATIVE', 'score': 0.901983916759491}
# {'label': 'NEGATIVE', 'score': 0.9972694516181946}
# {'label': 'POSITIVE', 'score': 0.9924010038375854}
# {'label': 'NEGATIVE', 'score': 0.9982637763023376}
# {'label': 'NEGATIVE', 'score': 0.9965973496437073}
# {'label': 'NEGATIVE', 'score': 0.9855999946594238}
# {'label': 'NEGATIVE', 'score': 0.9953598380088806}
# {'label': 'POSITIVE', 'score': 0.9967707395553589}
# {'label': 'NEGATIVE', 'score': 0.9853231906890869}
# {'label': 'NEGATIVE', 'score': 0.9907884001731873}
# {'label': 'NEGATIVE', 'score': 0.9672360420227051}
# {'label': 'NEGATIVE', 'score': 0.998256504535675}
# {'label': 'NEGATIVE', 'score': 0.945600688457489}
# {'label': 'NEGATIVE', 'score': 0.9972418546676636}
# {'label': 'NEGATIVE', 'score': 0.9976110458374023}
# {'label': 'NEGATIVE', 'score': 0.9992813467979431}
# {'label': 'NEGATIVE', 'score': 0.9925459027290344}
# {'label': 'POSITIVE', 'score': 0.9495117664337158}
# {'label': 'POSITIVE', 'score': 0.9622114896774292}
# {'label': 'NEGATIVE', 'score': 0.9992916584014893}
# {'label': 'NEGATIVE', 'score': 0.9933158755302429}
# {'label': 'NEGATIVE', 'score': 0.9992062449455261}
# {'label': 'NEGATIVE', 'score': 0.9842183589935303}
# {'label': 'NEGATIVE', 'score': 0.9995846152305603}
# {'label': 'NEGATIVE', 'score': 0.9897047877311707}
# {'label': 'NEGATIVE', 'score': 0.9995235204696655}
# {'label': 'NEGATIVE', 'score': 0.9997448325157166}
# {'label': 'NEGATIVE', 'score': 0.9987912774085999}
# {'label': 'NEGATIVE', 'score': 0.9984001517295837}
# {'label': 'NEGATIVE', 'score': 0.9958836436271667}
# {'label': 'NEGATIVE', 'score': 0.9996157884597778}
# {'label': 'NEGATIVE', 'score': 0.9994161128997803}
# {'label': 'NEGATIVE', 'score': 0.9997574687004089}
# {'label': 'NEGATIVE', 'score': 0.9997329115867615}
# {'label': 'NEGATIVE', 'score': 0.9997344613075256}
# {'label': 'POSITIVE', 'score': 0.9088491797447205}
# {'label': 'NEGATIVE', 'score': 0.9993467926979065}
# {'label': 'NEGATIVE', 'score': 0.9658187627792358}
# {'label': 'POSITIVE', 'score': 0.9798688292503357}
# {'label': 'NEGATIVE', 'score': 0.8674558997154236}
# {'label': 'NEGATIVE', 'score': 0.9856418967247009}
# {'label': 'NEGATIVE', 'score': 0.9993816614151001}
# {'label': 'NEGATIVE', 'score': 0.9995723366737366}
# {'label': 'NEGATIVE', 'score': 0.9936336278915405}
# {'label': 'NEGATIVE', 'score': 0.9989145994186401}
# {'label': 'NEGATIVE', 'score': 0.9877886176109314}
# {'label': 'NEGATIVE', 'score': 0.999692440032959}
# {'label': 'NEGATIVE', 'score': 0.9940482378005981}
# {'label': 'NEGATIVE', 'score': 0.9963842630386353}
# {'label': 'NEGATIVE', 'score': 0.9984295964241028}
# {'label': 'NEGATIVE', 'score': 0.9994794726371765}
# {'label': 'NEGATIVE', 'score': 0.9994621872901917}
# {'label': 'NEGATIVE', 'score': 0.9847972989082336}
# {'label': 'NEGATIVE', 'score': 0.9991835951805115}
# {'label': 'NEGATIVE', 'score': 0.6128451824188232}
# {'label': 'NEGATIVE', 'score': 0.9981189370155334}
# {'label': 'NEGATIVE', 'score': 0.9928332567214966}
# {'label': 'NEGATIVE', 'score': 0.9989290833473206}
# {'label': 'NEGATIVE', 'score': 0.9977982044219971}
# {'label': 'NEGATIVE', 'score': 0.996383786201477}
# {'label': 'NEGATIVE', 'score': 0.999103307723999}
# {'label': 'NEGATIVE', 'score': 0.9919008016586304}
# {'label': 'NEGATIVE', 'score': 0.5482344031333923}
# {'label': 'NEGATIVE', 'score': 0.9131811261177063}
# {'label': 'NEGATIVE', 'score': 0.9994516968727112}
# {'label': 'POSITIVE', 'score': 0.9712151885032654}
# {'label': 'NEGATIVE', 'score': 0.9979750514030457}
# {'label': 'NEGATIVE', 'score': 0.9968665242195129}
# {'label': 'NEGATIVE', 'score': 0.9968165755271912}
# {'label': 'POSITIVE', 'score': 0.8386877775192261}
# {'label': 'NEGATIVE', 'score': 0.9934325218200684}
# {'label': 'NEGATIVE', 'score': 0.9940535426139832}
# {'label': 'NEGATIVE', 'score': 0.9935259819030762}
# {'label': 'NEGATIVE', 'score': 0.9926143884658813}
# {'label': 'NEGATIVE', 'score': 0.9668389558792114}
# {'label': 'NEGATIVE', 'score': 0.9994757771492004}
# {'label': 'NEGATIVE', 'score': 0.9969151020050049}
# {'label': 'NEGATIVE', 'score': 0.9996668100357056}
# {'label': 'NEGATIVE', 'score': 0.9923257827758789}
# {'label': 'NEGATIVE', 'score': 0.9948744177818298}
# {'label': 'POSITIVE', 'score': 0.7630553245544434}
# {'label': 'NEGATIVE', 'score': 0.9990116357803345}
# {'label': 'NEGATIVE', 'score': 0.9901094436645508}
# {'label': 'NEGATIVE', 'score': 0.9992790818214417}
# {'label': 'NEGATIVE', 'score': 0.9275856614112854}
# {'label': 'NEGATIVE', 'score': 0.6967317461967468}
# {'label': 'NEGATIVE', 'score': 0.9987903237342834}
# {'label': 'POSITIVE', 'score': 0.7541617155075073}
# {'label': 'POSITIVE', 'score': 0.8909479379653931}
# {'label': 'NEGATIVE', 'score': 0.9829325675964355}
# {'label': 'NEGATIVE', 'score': 0.9765223264694214}
# {'label': 'NEGATIVE', 'score': 0.9974967837333679}
# {'label': 'NEGATIVE', 'score': 0.9956589937210083}
# {'label': 'POSITIVE', 'score': 0.9696044921875}
# {'label': 'NEGATIVE', 'score': 0.9976322650909424}
# {'label': 'NEGATIVE', 'score': 0.9975939393043518}
# {'label': 'POSITIVE', 'score': 0.9943854808807373}
# {'label': 'NEGATIVE', 'score': 0.9994418025016785}
# {'label': 'NEGATIVE', 'score': 0.6272962093353271}
# {'label': 'NEGATIVE', 'score': 0.9945811629295349}
# {'label': 'NEGATIVE', 'score': 0.9973335266113281}
# {'label': 'NEGATIVE', 'score': 0.9595391750335693}
# {'label': 'NEGATIVE', 'score': 0.9993031024932861}
# {'label': 'NEGATIVE', 'score': 0.9969642758369446}
# {'label': 'NEGATIVE', 'score': 0.9982057809829712}
# {'label': 'NEGATIVE', 'score': 0.9994046688079834}
# {'label': 'NEGATIVE', 'score': 0.9921919703483582}
# {'label': 'NEGATIVE', 'score': 0.9994491934776306}
# {'label': 'NEGATIVE', 'score': 0.9917134046554565}
# {'label': 'NEGATIVE', 'score': 0.9992485642433167}
# {'label': 'POSITIVE', 'score': 0.9936721324920654}
# {'label': 'POSITIVE', 'score': 0.9471737146377563}
# {'label': 'NEGATIVE', 'score': 0.9965341091156006}
# {'label': 'POSITIVE', 'score': 0.7400157451629639}
# {'label': 'NEGATIVE', 'score': 0.9957618117332458}
# {'label': 'NEGATIVE', 'score': 0.9789562821388245}
# {'label': 'NEGATIVE', 'score': 0.9841959476470947}
# {'label': 'NEGATIVE', 'score': 0.9939020872116089}
# {'label': 'NEGATIVE', 'score': 0.9972023963928223}
# {'label': 'POSITIVE', 'score': 0.9960604310035706}
# {'label': 'NEGATIVE', 'score': 0.9902745485305786}
# {'label': 'NEGATIVE', 'score': 0.9991278052330017}
# {'label': 'NEGATIVE', 'score': 0.9958617687225342}
# {'label': 'NEGATIVE', 'score': 0.9955087900161743}
# {'label': 'NEGATIVE', 'score': 0.9547138810157776}
# {'label': 'NEGATIVE', 'score': 0.9978359341621399}
# {'label': 'NEGATIVE', 'score': 0.9994127750396729}
# {'label': 'NEGATIVE', 'score': 0.9983586668968201}
# {'label': 'NEGATIVE', 'score': 0.9990569949150085}
# {'label': 'NEGATIVE', 'score': 0.9970657229423523}
# {'label': 'NEGATIVE', 'score': 0.9997673630714417}
# {'label': 'NEGATIVE', 'score': 0.9985120892524719}
# {'label': 'NEGATIVE', 'score': 0.9887929558753967}
# {'label': 'NEGATIVE', 'score': 0.998765230178833}
# {'label': 'NEGATIVE', 'score': 0.9967707395553589}
# {'label': 'NEGATIVE', 'score': 0.9982134103775024}
# {'label': 'NEGATIVE', 'score': 0.998946487903595}
# {'label': 'POSITIVE', 'score': 0.9895215034484863}
# {'label': 'NEGATIVE', 'score': 0.9986079335212708}
# {'label': 'NEGATIVE', 'score': 0.9997503161430359}
# {'label': 'NEGATIVE', 'score': 0.9985775947570801}
# {'label': 'NEGATIVE', 'score': 0.9947983026504517}
# {'label': 'NEGATIVE', 'score': 0.9967870712280273}
# {'label': 'NEGATIVE', 'score': 0.9995788931846619}
# {'label': 'NEGATIVE', 'score': 0.9996086955070496}
# {'label': 'NEGATIVE', 'score': 0.9970914125442505}
# {'label': 'NEGATIVE', 'score': 0.9994869232177734}
# {'label': 'NEGATIVE', 'score': 0.9980796575546265}
# {'label': 'NEGATIVE', 'score': 0.9996862411499023}
# {'label': 'NEGATIVE', 'score': 0.9991620779037476}
# {'label': 'NEGATIVE', 'score': 0.995571494102478}
# {'label': 'NEGATIVE', 'score': 0.8737037777900696}
# {'label': 'NEGATIVE', 'score': 0.9914271831512451}
# {'label': 'NEGATIVE', 'score': 0.9993355870246887}
# {'label': 'NEGATIVE', 'score': 0.9875856637954712}
# {'label': 'NEGATIVE', 'score': 0.9995433688163757}
# {'label': 'NEGATIVE', 'score': 0.9853911399841309}
# {'label': 'NEGATIVE', 'score': 0.9994120597839355}
# {'label': 'NEGATIVE', 'score': 0.9996962547302246}
# {'label': 'NEGATIVE', 'score': 0.9992554783821106}
# {'label': 'NEGATIVE', 'score': 0.9817833304405212}
# {'label': 'NEGATIVE', 'score': 0.9899961948394775}
# {'label': 'NEGATIVE', 'score': 0.997113823890686}
# {'label': 'NEGATIVE', 'score': 0.9936025738716125}
# {'label': 'NEGATIVE', 'score': 0.9810945987701416}
# {'label': 'NEGATIVE', 'score': 0.993763267993927}
# {'label': 'POSITIVE', 'score': 0.9788556694984436}
# {'label': 'NEGATIVE', 'score': 0.9967652559280396}
# {'label': 'NEGATIVE', 'score': 0.9987758994102478}
# {'label': 'NEGATIVE', 'score': 0.9993888139724731}
# {'label': 'POSITIVE', 'score': 0.9674166440963745}
# {'label': 'NEGATIVE', 'score': 0.9955267310142517}
# {'label': 'NEGATIVE', 'score': 0.9936597943305969}
# {'label': 'NEGATIVE', 'score': 0.9974320530891418}
# {'label': 'NEGATIVE', 'score': 0.6598051190376282}
# {'label': 'NEGATIVE', 'score': 0.9990803003311157}
# {'label': 'NEGATIVE', 'score': 0.998976469039917}
# {'label': 'NEGATIVE', 'score': 0.9997743964195251}
# {'label': 'NEGATIVE', 'score': 0.9893426895141602}
# {'label': 'NEGATIVE', 'score': 0.9972429275512695}
# {'label': 'NEGATIVE', 'score': 0.9986035227775574}
# {'label': 'NEGATIVE', 'score': 0.9996528625488281}
# {'label': 'NEGATIVE', 'score': 0.9996008276939392}
# {'label': 'NEGATIVE', 'score': 0.9564175009727478}
# {'label': 'POSITIVE', 'score': 0.7297306060791016}
# {'label': 'NEGATIVE', 'score': 0.995275616645813}
# {'label': 'NEGATIVE', 'score': 0.9908061623573303}
# {'label': 'NEGATIVE', 'score': 0.9993377327919006}
# {'label': 'NEGATIVE', 'score': 0.9942268133163452}
# {'label': 'NEGATIVE', 'score': 0.9954012632369995}
# {'label': 'NEGATIVE', 'score': 0.9991909861564636}
# {'label': 'NEGATIVE', 'score': 0.9797691106796265}
# {'label': 'NEGATIVE', 'score': 0.8934644460678101}
# {'label': 'NEGATIVE', 'score': 0.9590347409248352}
# {'label': 'NEGATIVE', 'score': 0.9994603991508484}
# {'label': 'NEGATIVE', 'score': 0.9996514320373535}
# {'label': 'NEGATIVE', 'score': 0.9995566010475159}
# {'label': 'NEGATIVE', 'score': 0.997308611869812}
# {'label': 'POSITIVE', 'score': 0.9351403117179871}
# {'label': 'NEGATIVE', 'score': 0.9660162925720215}
# {'label': 'NEGATIVE', 'score': 0.9952191710472107}
# {'label': 'NEGATIVE', 'score': 0.9988633394241333}
# {'label': 'NEGATIVE', 'score': 0.9595518112182617}
# {'label': 'NEGATIVE', 'score': 0.9953082203865051}
# {'label': 'NEGATIVE', 'score': 0.9985827207565308}
# {'label': 'NEGATIVE', 'score': 0.9995423555374146}
# {'label': 'NEGATIVE', 'score': 0.9226279258728027}
# {'label': 'NEGATIVE', 'score': 0.873395562171936}
# {'label': 'POSITIVE', 'score': 0.9353940486907959}
# {'label': 'NEGATIVE', 'score': 0.9585219025611877}
# {'label': 'NEGATIVE', 'score': 0.9992339611053467}
# {'label': 'NEGATIVE', 'score': 0.9962725639343262}
# {'label': 'NEGATIVE', 'score': 0.668509304523468}
# {'label': 'NEGATIVE', 'score': 0.9971600770950317}
# {'label': 'NEGATIVE', 'score': 0.9989013671875}
# {'label': 'NEGATIVE', 'score': 0.9978367686271667}
# {'label': 'NEGATIVE', 'score': 0.998372495174408}
# {'label': 'NEGATIVE', 'score': 0.9987706542015076}
# {'label': 'NEGATIVE', 'score': 0.9993962049484253}
# {'label': 'NEGATIVE', 'score': 0.9994938373565674}
# {'label': 'NEGATIVE', 'score': 0.9815123081207275}
# {'label': 'NEGATIVE', 'score': 0.9611313343048096}
# {'label': 'NEGATIVE', 'score': 0.9842151999473572}
# {'label': 'NEGATIVE', 'score': 0.8364203572273254}
# {'label': 'NEGATIVE', 'score': 0.9991280436515808}
# {'label': 'NEGATIVE', 'score': 0.9770429134368896}
# {'label': 'NEGATIVE', 'score': 0.8922758102416992}
# {'label': 'NEGATIVE', 'score': 0.9968042373657227}
# {'label': 'NEGATIVE', 'score': 0.9982771873474121}
# {'label': 'NEGATIVE', 'score': 0.9968619346618652}
# {'label': 'POSITIVE', 'score': 0.9666419625282288}
# {'label': 'NEGATIVE', 'score': 0.9826623201370239}
# {'label': 'POSITIVE', 'score': 0.7286195158958435}
# {'label': 'NEGATIVE', 'score': 0.9978862404823303}
# {'label': 'NEGATIVE', 'score': 0.9997108578681946}
# {'label': 'NEGATIVE', 'score': 0.9988917708396912}
# {'label': 'NEGATIVE', 'score': 0.9996892213821411}
# {'label': 'NEGATIVE', 'score': 0.9636713862419128}
# {'label': 'NEGATIVE', 'score': 0.9992844462394714}
# {'label': 'NEGATIVE', 'score': 0.9855883121490479}
# {'label': 'NEGATIVE', 'score': 0.992480993270874}
# {'label': 'NEGATIVE', 'score': 0.9997348189353943}
# {'label': 'NEGATIVE', 'score': 0.9854031801223755}
# {'label': 'NEGATIVE', 'score': 0.9997499585151672}
# {'label': 'NEGATIVE', 'score': 0.9941607117652893}
# {'label': 'NEGATIVE', 'score': 0.9997338652610779}
# {'label': 'NEGATIVE', 'score': 0.965530276298523}
# {'label': 'NEGATIVE', 'score': 0.9813461899757385}
# {'label': 'NEGATIVE', 'score': 0.9980117082595825}
# {'label': 'NEGATIVE', 'score': 0.9993915557861328}
# {'label': 'NEGATIVE', 'score': 0.9958336353302002}
# {'label': 'NEGATIVE', 'score': 0.9941773414611816}
# {'label': 'NEGATIVE', 'score': 0.9959198236465454}
# {'label': 'NEGATIVE', 'score': 0.9143242835998535}
# {'label': 'NEGATIVE', 'score': 0.9990233182907104}
# {'label': 'NEGATIVE', 'score': 0.9996858835220337}
# {'label': 'NEGATIVE', 'score': 0.9989911913871765}
# {'label': 'NEGATIVE', 'score': 0.8659266233444214}
# {'label': 'NEGATIVE', 'score': 0.9975396394729614}
# {'label': 'NEGATIVE', 'score': 0.9995655417442322}
# {'label': 'NEGATIVE', 'score': 0.9997988343238831}
# {'label': 'NEGATIVE', 'score': 0.9997988343238831}
# {'label': 'NEGATIVE', 'score': 0.9997041821479797}
# {'label': 'NEGATIVE', 'score': 0.9996535778045654}
# {'label': 'NEGATIVE', 'score': 0.988801121711731}
# {'label': 'NEGATIVE', 'score': 0.9995237588882446}
# {'label': 'NEGATIVE', 'score': 0.999039351940155}
# {'label': 'NEGATIVE', 'score': 0.9986935257911682}
# {'label': 'NEGATIVE', 'score': 0.9934148788452148}
# {'label': 'NEGATIVE', 'score': 0.9937658309936523}
# {'label': 'NEGATIVE', 'score': 0.9993903636932373}
# {'label': 'NEGATIVE', 'score': 0.9968137145042419}
# {'label': 'NEGATIVE', 'score': 0.9977353811264038}
# {'label': 'NEGATIVE', 'score': 0.9927634596824646}
# {'label': 'NEGATIVE', 'score': 0.9988318085670471}
# {'label': 'NEGATIVE', 'score': 0.9979735016822815}
# {'label': 'NEGATIVE', 'score': 0.9997207522392273}
# {'label': 'NEGATIVE', 'score': 0.9949041604995728}
# {'label': 'NEGATIVE', 'score': 0.9975337982177734}
# {'label': 'NEGATIVE', 'score': 0.9989474415779114}
# {'label': 'NEGATIVE', 'score': 0.9907559752464294}
# {'label': 'NEGATIVE', 'score': 0.9908139109611511}
# {'label': 'NEGATIVE', 'score': 0.9761345982551575}
# {'label': 'NEGATIVE', 'score': 0.9917744994163513}
# {'label': 'NEGATIVE', 'score': 0.986855149269104}
# {'label': 'NEGATIVE', 'score': 0.9975882768630981}
# {'label': 'NEGATIVE', 'score': 0.9972324967384338}
# {'label': 'NEGATIVE', 'score': 0.9980996251106262}
# {'label': 'NEGATIVE', 'score': 0.999362051486969}
# {'label': 'NEGATIVE', 'score': 0.9936566948890686}
# {'label': 'NEGATIVE', 'score': 0.9981163740158081}
# {'label': 'NEGATIVE', 'score': 0.999613344669342}
# {'label': 'NEGATIVE', 'score': 0.9950628876686096}
# {'label': 'NEGATIVE', 'score': 0.9986929297447205}
# {'label': 'NEGATIVE', 'score': 0.993064820766449}
# {'label': 'NEGATIVE', 'score': 0.9972379207611084}
# {'label': 'NEGATIVE', 'score': 0.9842476844787598}
# {'label': 'NEGATIVE', 'score': 0.9992973804473877}
# {'label': 'NEGATIVE', 'score': 0.9842476844787598}
# {'label': 'NEGATIVE', 'score': 0.9892562627792358}
# {'label': 'NEGATIVE', 'score': 0.9897140264511108}
# {'label': 'NEGATIVE', 'score': 0.9436109662055969}
# {'label': 'NEGATIVE', 'score': 0.9973766803741455}
# {'label': 'NEGATIVE', 'score': 0.7458009719848633}
# {'label': 'POSITIVE', 'score': 0.5641984939575195}
# {'label': 'NEGATIVE', 'score': 0.9994457364082336}
# {'label': 'POSITIVE', 'score': 0.9152683019638062}
# {'label': 'NEGATIVE', 'score': 0.8182606101036072}
# {'label': 'NEGATIVE', 'score': 0.9857423305511475}
# {'label': 'NEGATIVE', 'score': 0.9976534247398376}
# {'label': 'NEGATIVE', 'score': 0.9995390176773071}
# {'label': 'NEGATIVE', 'score': 0.9967676401138306}
# {'label': 'NEGATIVE', 'score': 0.992996871471405}
# {'label': 'NEGATIVE', 'score': 0.9996323585510254}
# {'label': 'NEGATIVE', 'score': 0.9945293068885803}
# {'label': 'NEGATIVE', 'score': 0.9831579923629761}
# {'label': 'NEGATIVE', 'score': 0.967787504196167}
# {'label': 'NEGATIVE', 'score': 0.990395724773407}
# {'label': 'POSITIVE', 'score': 0.7762346267700195}
# {'label': 'NEGATIVE', 'score': 0.9993622899055481}
# {'label': 'NEGATIVE', 'score': 0.9967959523200989}
# {'label': 'NEGATIVE', 'score': 0.9913416504859924}
# {'label': 'NEGATIVE', 'score': 0.999455988407135}
# {'label': 'NEGATIVE', 'score': 0.998379111289978}
# {'label': 'POSITIVE', 'score': 0.73345547914505}
# {'label': 'NEGATIVE', 'score': 0.6540025472640991}
# {'label': 'POSITIVE', 'score': 0.8201360106468201}
# {'label': 'NEGATIVE', 'score': 0.9980036616325378}
# {'label': 'NEGATIVE', 'score': 0.9977356195449829}
# {'label': 'NEGATIVE', 'score': 0.9878778457641602}
# {'label': 'NEGATIVE', 'score': 0.9983637928962708}
# {'label': 'NEGATIVE', 'score': 0.9997345805168152}
# {'label': 'NEGATIVE', 'score': 0.9957960844039917}
# {'label': 'NEGATIVE', 'score': 0.9978793859481812}
# {'label': 'NEGATIVE', 'score': 0.998790442943573}
# {'label': 'NEGATIVE', 'score': 0.9947320222854614}
# {'label': 'POSITIVE', 'score': 0.9690054059028625}
# {'label': 'NEGATIVE', 'score': 0.990637481212616}
# {'label': 'NEGATIVE', 'score': 0.999632716178894}
# {'label': 'NEGATIVE', 'score': 0.9985561966896057}
# {'label': 'NEGATIVE', 'score': 0.9964021444320679}
# {'label': 'NEGATIVE', 'score': 0.9996036887168884}
# {'label': 'NEGATIVE', 'score': 0.9991353154182434}
# {'label': 'NEGATIVE', 'score': 0.9992690682411194}
# {'label': 'NEGATIVE', 'score': 0.9995591044425964}
# {'label': 'NEGATIVE', 'score': 0.9995529055595398}
# {'label': 'NEGATIVE', 'score': 0.9995803236961365}
# {'label': 'NEGATIVE', 'score': 0.9943596720695496}
# {'label': 'NEGATIVE', 'score': 0.999138593673706}
# {'label': 'NEGATIVE', 'score': 0.9996032118797302}
# {'label': 'NEGATIVE', 'score': 0.9863384366035461}
# {'label': 'NEGATIVE', 'score': 0.9994218349456787}
# {'label': 'NEGATIVE', 'score': 0.9996374845504761}
# {'label': 'NEGATIVE', 'score': 0.9878627061843872}
# {'label': 'NEGATIVE', 'score': 0.9996111989021301}
# {'label': 'NEGATIVE', 'score': 0.9933061003684998}
# {'label': 'NEGATIVE', 'score': 0.9982544779777527}
# {'label': 'NEGATIVE', 'score': 0.9980589747428894}
# {'label': 'NEGATIVE', 'score': 0.9994644522666931}
# {'label': 'NEGATIVE', 'score': 0.9985917210578918}
# {'label': 'NEGATIVE', 'score': 0.9972912669181824}
# {'label': 'NEGATIVE', 'score': 0.999602735042572}
# {'label': 'NEGATIVE', 'score': 0.9980547428131104}
# {'label': 'POSITIVE', 'score': 0.9910921454429626}
# {'label': 'POSITIVE', 'score': 0.6671547889709473}
# {'label': 'NEGATIVE', 'score': 0.9986288547515869}
# {'label': 'NEGATIVE', 'score': 0.9983277916908264}
# {'label': 'NEGATIVE', 'score': 0.999606192111969}
# {'label': 'NEGATIVE', 'score': 0.9968110918998718}
# {'label': 'NEGATIVE', 'score': 0.994001567363739}
# {'label': 'NEGATIVE', 'score': 0.9996446371078491}
# {'label': 'POSITIVE', 'score': 0.7871705889701843}
# {'label': 'NEGATIVE', 'score': 0.989891767501831}
# {'label': 'NEGATIVE', 'score': 0.9961498975753784}
# {'label': 'NEGATIVE', 'score': 0.8371900916099548}
# {'label': 'NEGATIVE', 'score': 0.9976933598518372}
# {'label': 'NEGATIVE', 'score': 0.9981594681739807}
# {'label': 'NEGATIVE', 'score': 0.9991722106933594}
# {'label': 'POSITIVE', 'score': 0.6571232676506042}
# {'label': 'NEGATIVE', 'score': 0.9991740584373474}
# {'label': 'NEGATIVE', 'score': 0.981813907623291}
# {'label': 'NEGATIVE', 'score': 0.9980402588844299}
# {'label': 'NEGATIVE', 'score': 0.9896356463432312}
# {'label': 'NEGATIVE', 'score': 0.9906800389289856}
# {'label': 'NEGATIVE', 'score': 0.9697060585021973}
# {'label': 'POSITIVE', 'score': 0.9384211897850037}
# {'label': 'NEGATIVE', 'score': 0.9983409643173218}
# {'label': 'NEGATIVE', 'score': 0.9582135677337646}
# {'label': 'NEGATIVE', 'score': 0.9994188547134399}
# {'label': 'NEGATIVE', 'score': 0.9983609318733215}
# {'label': 'NEGATIVE', 'score': 0.9936403632164001}
# {'label': 'POSITIVE', 'score': 0.6199368238449097}
# {'label': 'NEGATIVE', 'score': 0.9852059483528137}
# {'label': 'POSITIVE', 'score': 0.7063152194023132}
# {'label': 'NEGATIVE', 'score': 0.9716843366622925}
# {'label': 'NEGATIVE', 'score': 0.9997579455375671}
# {'label': 'POSITIVE', 'score': 0.640006959438324}
# {'label': 'NEGATIVE', 'score': 0.9956152439117432}
# {'label': 'NEGATIVE', 'score': 0.9971791505813599}
# {'label': 'NEGATIVE', 'score': 0.997718870639801}
# {'label': 'NEGATIVE', 'score': 0.9992685914039612}
# {'label': 'NEGATIVE', 'score': 0.9992994070053101}
# {'label': 'NEGATIVE', 'score': 0.9990315437316895}
# {'label': 'NEGATIVE', 'score': 0.9990664124488831}
# {'label': 'NEGATIVE', 'score': 0.9971476197242737}
# {'label': 'NEGATIVE', 'score': 0.909080445766449}
# {'label': 'NEGATIVE', 'score': 0.9897508025169373}
# {'label': 'NEGATIVE', 'score': 0.9952473044395447}
# {'label': 'NEGATIVE', 'score': 0.9863126873970032}
# {'label': 'NEGATIVE', 'score': 0.9943766593933105}
# {'label': 'NEGATIVE', 'score': 0.9979861974716187}
# {'label': 'NEGATIVE', 'score': 0.9480538368225098}
# {'label': 'NEGATIVE', 'score': 0.998874843120575}
# {'label': 'NEGATIVE', 'score': 0.9955293536186218}
# {'label': 'NEGATIVE', 'score': 0.9970483183860779}
# {'label': 'NEGATIVE', 'score': 0.9990938901901245}
# {'label': 'NEGATIVE', 'score': 0.999748170375824}
# {'label': 'NEGATIVE', 'score': 0.9985219836235046}
# {'label': 'NEGATIVE', 'score': 0.9997116923332214}
# {'label': 'NEGATIVE', 'score': 0.9943238496780396}
# {'label': 'NEGATIVE', 'score': 0.9658216238021851}
# {'label': 'NEGATIVE', 'score': 0.9922067523002625}
# {'label': 'NEGATIVE', 'score': 0.997334897518158}
# {'label': 'NEGATIVE', 'score': 0.9973588585853577}
# {'label': 'POSITIVE', 'score': 0.9875969290733337}
# {'label': 'NEGATIVE', 'score': 0.9759854078292847}
# {'label': 'NEGATIVE', 'score': 0.9979133009910583}
# {'label': 'NEGATIVE', 'score': 0.9997376799583435}
# {'label': 'NEGATIVE', 'score': 0.9965820908546448}
# {'label': 'NEGATIVE', 'score': 0.9973886609077454}
# {'label': 'NEGATIVE', 'score': 0.9992734789848328}
# {'label': 'NEGATIVE', 'score': 0.9911090135574341}
# {'label': 'NEGATIVE', 'score': 0.9446262717247009}
# {'label': 'NEGATIVE', 'score': 0.8418644666671753}
# {'label': 'NEGATIVE', 'score': 0.976144015789032}
# {'label': 'POSITIVE', 'score': 0.9329343438148499}
# {'label': 'NEGATIVE', 'score': 0.9992569088935852}
# {'label': 'NEGATIVE', 'score': 0.9984720349311829}
# {'label': 'NEGATIVE', 'score': 0.9994600415229797}
# {'label': 'NEGATIVE', 'score': 0.8282514810562134}
# {'label': 'NEGATIVE', 'score': 0.9992743134498596}
# {'label': 'NEGATIVE', 'score': 0.9997268319129944}
# {'label': 'NEGATIVE', 'score': 0.992845356464386}
# {'label': 'NEGATIVE', 'score': 0.9925253391265869}
# {'label': 'NEGATIVE', 'score': 0.997936487197876}
# {'label': 'NEGATIVE', 'score': 0.9972671270370483}
# {'label': 'NEGATIVE', 'score': 0.9996156692504883}
# {'label': 'NEGATIVE', 'score': 0.9939570426940918}
# {'label': 'NEGATIVE', 'score': 0.9913243055343628}
# {'label': 'NEGATIVE', 'score': 0.9989318251609802}
# {'label': 'POSITIVE', 'score': 0.9971517324447632}
# {'label': 'NEGATIVE', 'score': 0.9954043626785278}
# {'label': 'NEGATIVE', 'score': 0.9974691867828369}
# {'label': 'NEGATIVE', 'score': 0.9995977282524109}
# {'label': 'NEGATIVE', 'score': 0.9995751976966858}
# {'label': 'NEGATIVE', 'score': 0.9968459010124207}
# {'label': 'NEGATIVE', 'score': 0.994928240776062}
# {'label': 'NEGATIVE', 'score': 0.8551311492919922}
# {'label': 'NEGATIVE', 'score': 0.812861979007721}
# {'label': 'POSITIVE', 'score': 0.9903402924537659}
# {'label': 'NEGATIVE', 'score': 0.9965458512306213}
# {'label': 'NEGATIVE', 'score': 0.9876950979232788}
# {'label': 'NEGATIVE', 'score': 0.9409402012825012}
# {'label': 'NEGATIVE', 'score': 0.9997100234031677}
# {'label': 'NEGATIVE', 'score': 0.9974818825721741}
# {'label': 'NEGATIVE', 'score': 0.8142857551574707}
# {'label': 'NEGATIVE', 'score': 0.9994718432426453}
# {'label': 'NEGATIVE', 'score': 0.9959056377410889}
# {'label': 'NEGATIVE', 'score': 0.9630284905433655}
# {'label': 'NEGATIVE', 'score': 0.9846343398094177}
# {'label': 'NEGATIVE', 'score': 0.9993818998336792}
# {'label': 'NEGATIVE', 'score': 0.99366295337677}
# {'label': 'NEGATIVE', 'score': 0.9994254112243652}
# {'label': 'NEGATIVE', 'score': 0.5800451636314392}
# {'label': 'POSITIVE', 'score': 0.8738560080528259}
# {'label': 'NEGATIVE', 'score': 0.9893019795417786}
# {'label': 'NEGATIVE', 'score': 0.9973155856132507}
# {'label': 'NEGATIVE', 'score': 0.9996851682662964}
# {'label': 'NEGATIVE', 'score': 0.9950177073478699}
# {'label': 'NEGATIVE', 'score': 0.9987741112709045}
# {'label': 'NEGATIVE', 'score': 0.9990767240524292}
# {'label': 'NEGATIVE', 'score': 0.9990184307098389}
# {'label': 'NEGATIVE', 'score': 0.9942359328269958}
# {'label': 'NEGATIVE', 'score': 0.9692493677139282}
# {'label': 'NEGATIVE', 'score': 0.999238133430481}
# {'label': 'NEGATIVE', 'score': 0.8757606148719788}
# {'label': 'NEGATIVE', 'score': 0.9980992674827576}
# {'label': 'NEGATIVE', 'score': 0.9979255199432373}
# {'label': 'POSITIVE', 'score': 0.7804417610168457}
# {'label': 'NEGATIVE', 'score': 0.999089241027832}
# {'label': 'NEGATIVE', 'score': 0.9944750666618347}
# {'label': 'NEGATIVE', 'score': 0.9984381794929504}
# {'label': 'NEGATIVE', 'score': 0.9915458559989929}
# {'label': 'POSITIVE', 'score': 0.8777017593383789}
# {'label': 'NEGATIVE', 'score': 0.9966768026351929}
# {'label': 'NEGATIVE', 'score': 0.9642658829689026}
# {'label': 'NEGATIVE', 'score': 0.995046854019165}
# {'label': 'NEGATIVE', 'score': 0.9868159890174866}
# {'label': 'NEGATIVE', 'score': 0.9430844783782959}
# {'label': 'NEGATIVE', 'score': 0.9989941716194153}
# {'label': 'NEGATIVE', 'score': 0.9960039258003235}
# {'label': 'NEGATIVE', 'score': 0.9998176693916321}
# {'label': 'NEGATIVE', 'score': 0.9795407652854919}
# {'label': 'NEGATIVE', 'score': 0.9945421814918518}
# {'label': 'NEGATIVE', 'score': 0.9975295662879944}
# {'label': 'NEGATIVE', 'score': 0.9995757937431335}
# {'label': 'NEGATIVE', 'score': 0.9951711297035217}
# {'label': 'NEGATIVE', 'score': 0.987135112285614}
# {'label': 'NEGATIVE', 'score': 0.9997724890708923}
# {'label': 'NEGATIVE', 'score': 0.9978097081184387}
# {'label': 'NEGATIVE', 'score': 0.9946461319923401}
# {'label': 'POSITIVE', 'score': 0.993865430355072}
# {'label': 'POSITIVE', 'score': 0.6302902102470398}
# {'label': 'NEGATIVE', 'score': 0.9587277770042419}
# {'label': 'NEGATIVE', 'score': 0.9997664093971252}
# {'label': 'NEGATIVE', 'score': 0.9995179176330566}
# {'label': 'NEGATIVE', 'score': 0.9962814450263977}
# {'label': 'NEGATIVE', 'score': 0.9871909618377686}
# {'label': 'NEGATIVE', 'score': 0.9996331930160522}
# {'label': 'NEGATIVE', 'score': 0.996884286403656}
# {'label': 'NEGATIVE', 'score': 0.9991158843040466}
# {'label': 'NEGATIVE', 'score': 0.9922802448272705}
# {'label': 'NEGATIVE', 'score': 0.9989092350006104}
# {'label': 'NEGATIVE', 'score': 0.9982903599739075}
# {'label': 'NEGATIVE', 'score': 0.9995723366737366}
# {'label': 'NEGATIVE', 'score': 0.9263126850128174}
# {'label': 'NEGATIVE', 'score': 0.8822011351585388}
# {'label': 'NEGATIVE', 'score': 0.9963911175727844}
# ...
# {'label': 'POSITIVE', 'score': 0.9969437718391418}
# {'label': 'POSITIVE', 'score': 0.9997333884239197}
# {'label': 'POSITIVE', 'score': 0.9971733093261719}
# {'label': 'NEGATIVE', 'score': 0.673206627368927}
# {'label': 'POSITIVE', 'score': 0.9945499300956726}
# {'label': 'POSITIVE', 'score': 0.997067391872406}
# {'label': 'POSITIVE', 'score': 0.9977959394454956}
# {'label': 'POSITIVE', 'score': 0.9979270696640015}
# {'label': 'POSITIVE', 'score': 0.99253910779953}
# {'label': 'POSITIVE', 'score': 0.9993491768836975}
# {'label': 'NEGATIVE', 'score': 0.9767042398452759}
# {'label': 'POSITIVE', 'score': 0.9778932929039001}
# {'label': 'NEGATIVE', 'score': 0.7180639505386353}
# {'label': 'NEGATIVE', 'score': 0.8206126093864441}
# {'label': 'POSITIVE', 'score': 0.99922776222229}
# {'label': 'POSITIVE', 'score': 0.998691976070404}
# {'label': 'POSITIVE', 'score': 0.9162343144416809}
# {'label': 'NEGATIVE', 'score': 0.7724220156669617}
# {'label': 'POSITIVE', 'score': 0.9993244409561157}
# {'label': 'NEGATIVE', 'score': 0.5664700269699097}
# {'label': 'NEGATIVE', 'score': 0.994706928730011}
# {'label': 'POSITIVE', 'score': 0.9985112547874451}
# {'label': 'POSITIVE', 'score': 0.9927859902381897}
# {'label': 'NEGATIVE', 'score': 0.9464716911315918}
# {'label': 'POSITIVE', 'score': 0.997431218624115}
# {'label': 'POSITIVE', 'score': 0.9943115711212158}
# {'label': 'NEGATIVE', 'score': 0.951616644859314}
# {'label': 'NEGATIVE', 'score': 0.9784255623817444}
# {'label': 'POSITIVE', 'score': 0.996629536151886}
# {'label': 'NEGATIVE', 'score': 0.9865865707397461}
# {'label': 'NEGATIVE', 'score': 0.9897129535675049}
# {'label': 'NEGATIVE', 'score': 0.988444447517395}
# {'label': 'POSITIVE', 'score': 0.998157799243927}
# {'label': 'NEGATIVE', 'score': 0.9773385524749756}
# {'label': 'POSITIVE', 'score': 0.995559573173523}
# {'label': 'POSITIVE', 'score': 0.9989495873451233}
# {'label': 'POSITIVE', 'score': 0.9984561204910278}
# {'label': 'POSITIVE', 'score': 0.9067997932434082}
# {'label': 'POSITIVE', 'score': 0.9927898049354553}
# {'label': 'NEGATIVE', 'score': 0.9813134670257568}
# {'label': 'POSITIVE', 'score': 0.998806357383728}
# {'label': 'POSITIVE', 'score': 0.9993873834609985}
# {'label': 'NEGATIVE', 'score': 0.9496275186538696}
# {'label': 'NEGATIVE', 'score': 0.6834204196929932}
# {'label': 'POSITIVE', 'score': 0.9795754551887512}
# {'label': 'POSITIVE', 'score': 0.8690747022628784}
# {'label': 'POSITIVE', 'score': 0.9996861219406128}
# {'label': 'POSITIVE', 'score': 0.9962936043739319}
# {'label': 'POSITIVE', 'score': 0.9994489550590515}
# {'label': 'POSITIVE', 'score': 0.9983097314834595}
# {'label': 'POSITIVE', 'score': 0.9998531341552734}
# {'label': 'POSITIVE', 'score': 0.9933642148971558}
# {'label': 'POSITIVE', 'score': 0.9916634559631348}
# {'label': 'NEGATIVE', 'score': 0.9983726143836975}
# {'label': 'POSITIVE', 'score': 0.9973674416542053}
# {'label': 'POSITIVE', 'score': 0.9984684586524963}
# {'label': 'NEGATIVE', 'score': 0.9547777771949768}
# {'label': 'POSITIVE', 'score': 0.9945780038833618}
# {'label': 'POSITIVE', 'score': 0.9995877146720886}
# {'label': 'POSITIVE', 'score': 0.9810665845870972}
# {'label': 'POSITIVE', 'score': 0.9981922507286072}
# {'label': 'POSITIVE', 'score': 0.6516427993774414}
# {'label': 'POSITIVE', 'score': 0.9163438081741333}
# {'label': 'NEGATIVE', 'score': 0.9800866842269897}
# {'label': 'POSITIVE', 'score': 0.9934083223342896}
# {'label': 'POSITIVE', 'score': 0.9574328064918518}
# {'label': 'NEGATIVE', 'score': 0.9906131029129028}
# {'label': 'NEGATIVE', 'score': 0.9875348806381226}
# {'label': 'POSITIVE', 'score': 0.9997307658195496}
# {'label': 'POSITIVE', 'score': 0.9323917031288147}
# {'label': 'NEGATIVE', 'score': 0.9590008854866028}
# {'label': 'NEGATIVE', 'score': 0.9461095929145813}
# {'label': 'NEGATIVE', 'score': 0.9986078143119812}
# {'label': 'POSITIVE', 'score': 0.9966015815734863}
# {'label': 'POSITIVE', 'score': 0.5240516662597656}
# {'label': 'NEGATIVE', 'score': 0.9978227615356445}
# {'label': 'POSITIVE', 'score': 0.9988192915916443}
# {'label': 'POSITIVE', 'score': 0.9995554089546204}
# {'label': 'POSITIVE', 'score': 0.6502309441566467}
# {'label': 'POSITIVE', 'score': 0.9785076379776001}
# {'label': 'POSITIVE', 'score': 0.5331200957298279}
# {'label': 'POSITIVE', 'score': 0.9997212290763855}
# {'label': 'POSITIVE', 'score': 0.9844591617584229}
# {'label': 'NEGATIVE', 'score': 0.9923335313796997}
# {'label': 'POSITIVE', 'score': 0.9810173511505127}
# {'label': 'POSITIVE', 'score': 0.9962891340255737}
# {'label': 'NEGATIVE', 'score': 0.9504101276397705}
# {'label': 'POSITIVE', 'score': 0.9777832627296448}
# {'label': 'POSITIVE', 'score': 0.9970182180404663}
# {'label': 'POSITIVE', 'score': 0.9932708144187927}
# {'label': 'POSITIVE', 'score': 0.9567518830299377}
# {'label': 'POSITIVE', 'score': 0.7661386132240295}
# {'label': 'POSITIVE', 'score': 0.9935142993927002}
# {'label': 'NEGATIVE', 'score': 0.9220399856567383}
# {'label': 'POSITIVE', 'score': 0.8235191106796265}
# {'label': 'POSITIVE', 'score': 0.9994537234306335}
# {'label': 'NEGATIVE', 'score': 0.987210750579834}
# {'label': 'NEGATIVE', 'score': 0.8737978339195251}
# {'label': 'POSITIVE', 'score': 0.9954935312271118}
# {'label': 'NEGATIVE', 'score': 0.9749577641487122}
# {'label': 'POSITIVE', 'score': 0.8097911477088928}
# {'label': 'POSITIVE', 'score': 0.9996966123580933}
# {'label': 'POSITIVE', 'score': 0.9910174608230591}
# {'label': 'POSITIVE', 'score': 0.9945026636123657}
# {'label': 'POSITIVE', 'score': 0.9997269511222839}
# {'label': 'POSITIVE', 'score': 0.9670574069023132}
# {'label': 'POSITIVE', 'score': 0.8829963207244873}
# {'label': 'NEGATIVE', 'score': 0.56526118516922}
# {'label': 'POSITIVE', 'score': 0.9953473210334778}
# {'label': 'POSITIVE', 'score': 0.9988284707069397}
# {'label': 'POSITIVE', 'score': 0.927366316318512}
# {'label': 'POSITIVE', 'score': 0.9969885945320129}
# {'label': 'POSITIVE', 'score': 0.983314037322998}
# {'label': 'POSITIVE', 'score': 0.989207923412323}
# {'label': 'POSITIVE', 'score': 0.932552695274353}
# {'label': 'NEGATIVE', 'score': 0.9664050936698914}
# {'label': 'NEGATIVE', 'score': 0.971367597579956}
# {'label': 'POSITIVE', 'score': 0.9851865172386169}
# {'label': 'NEGATIVE', 'score': 0.69117671251297}
# {'label': 'NEGATIVE', 'score': 0.9696611166000366}
# {'label': 'NEGATIVE', 'score': 0.9949835538864136}
# {'label': 'POSITIVE', 'score': 0.9997307658195496}
# {'label': 'POSITIVE', 'score': 0.9996838569641113}
# {'label': 'POSITIVE', 'score': 0.999840259552002}
# {'label': 'NEGATIVE', 'score': 0.8905203342437744}
# {'label': 'NEGATIVE', 'score': 0.9155638217926025}
# {'label': 'POSITIVE', 'score': 0.99118572473526}
# {'label': 'POSITIVE', 'score': 0.9952313303947449}
# {'label': 'POSITIVE', 'score': 0.9626451134681702}
# {'label': 'POSITIVE', 'score': 0.9976813793182373}
# {'label': 'POSITIVE', 'score': 0.9947792291641235}
# {'label': 'NEGATIVE', 'score': 0.9886464476585388}
# {'label': 'NEGATIVE', 'score': 0.9876660108566284}
# {'label': 'POSITIVE', 'score': 0.8628315329551697}
# {'label': 'POSITIVE', 'score': 0.9983822107315063}
# {'label': 'POSITIVE', 'score': 0.6850031614303589}
# {'label': 'POSITIVE', 'score': 0.9640762805938721}
# {'label': 'POSITIVE', 'score': 0.970767617225647}
# {'label': 'POSITIVE', 'score': 0.998008668422699}
# {'label': 'NEGATIVE', 'score': 0.8894954919815063}
# {'label': 'POSITIVE', 'score': 0.9937005043029785}
# {'label': 'POSITIVE', 'score': 0.9930510520935059}
# {'label': 'POSITIVE', 'score': 0.7052950859069824}
# {'label': 'POSITIVE', 'score': 0.8070948123931885}
# {'label': 'POSITIVE', 'score': 0.9960964322090149}
# {'label': 'POSITIVE', 'score': 0.9980583786964417}
# {'label': 'POSITIVE', 'score': 0.9744277596473694}
# {'label': 'POSITIVE', 'score': 0.99431312084198}
# {'label': 'NEGATIVE', 'score': 0.9960805773735046}
# {'label': 'POSITIVE', 'score': 0.9501538276672363}
# {'label': 'POSITIVE', 'score': 0.9654850363731384}
# {'label': 'POSITIVE', 'score': 0.9991921782493591}
# {'label': 'NEGATIVE', 'score': 0.9954676628112793}
# {'label': 'POSITIVE', 'score': 0.9982847571372986}
# {'label': 'POSITIVE', 'score': 0.720884382724762}
# {'label': 'NEGATIVE', 'score': 0.9816786646842957}
# {'label': 'NEGATIVE', 'score': 0.9848432540893555}
# {'label': 'POSITIVE', 'score': 0.5277836322784424}
# {'label': 'POSITIVE', 'score': 0.9994409680366516}
# {'label': 'POSITIVE', 'score': 0.9996455907821655}
# {'label': 'POSITIVE', 'score': 0.9995902180671692}
# {'label': 'POSITIVE', 'score': 0.999377965927124}
# {'label': 'NEGATIVE', 'score': 0.9633927941322327}
# {'label': 'POSITIVE', 'score': 0.9993578791618347}
# {'label': 'POSITIVE', 'score': 0.9972744584083557}
# {'label': 'POSITIVE', 'score': 0.9998199343681335}
# {'label': 'POSITIVE', 'score': 0.9953339695930481}
# {'label': 'POSITIVE', 'score': 0.9985281229019165}
# {'label': 'POSITIVE', 'score': 0.9995715022087097}
# {'label': 'POSITIVE', 'score': 0.9992018342018127}
# {'label': 'POSITIVE', 'score': 0.9996384382247925}
# {'label': 'POSITIVE', 'score': 0.999828577041626}
# {'label': 'POSITIVE', 'score': 0.9996436834335327}
# {'label': 'POSITIVE', 'score': 0.5661396384239197}
# {'label': 'NEGATIVE', 'score': 0.9829686284065247}
# {'label': 'NEGATIVE', 'score': 0.9409846663475037}
# {'label': 'NEGATIVE', 'score': 0.754205048084259}
# {'label': 'POSITIVE', 'score': 0.9832425117492676}
# {'label': 'POSITIVE', 'score': 0.9774640202522278}
# {'label': 'POSITIVE', 'score': 0.9998292922973633}
# {'label': 'NEGATIVE', 'score': 0.9197824597358704}
# {'label': 'POSITIVE', 'score': 0.9993792772293091}
# {'label': 'POSITIVE', 'score': 0.8046565651893616}
# {'label': 'NEGATIVE', 'score': 0.9633695483207703}
# {'label': 'POSITIVE', 'score': 0.9786604046821594}
# {'label': 'NEGATIVE', 'score': 0.9934230446815491}
# {'label': 'POSITIVE', 'score': 0.9948628544807434}
# {'label': 'POSITIVE', 'score': 0.969773530960083}
# {'label': 'NEGATIVE', 'score': 0.995158851146698}
# {'label': 'POSITIVE', 'score': 0.9972600936889648}
# {'label': 'POSITIVE', 'score': 0.9993390440940857}
# {'label': 'POSITIVE', 'score': 0.9988638162612915}
# {'label': 'NEGATIVE', 'score': 0.9254380464553833}
# {'label': 'POSITIVE', 'score': 0.9998403787612915}
# {'label': 'POSITIVE', 'score': 0.9998536109924316}
# {'label': 'POSITIVE', 'score': 0.9985851049423218}
# {'label': 'POSITIVE', 'score': 0.999200165271759}
# {'label': 'POSITIVE', 'score': 0.9967267513275146}
# {'label': 'POSITIVE', 'score': 0.9965852499008179}
# {'label': 'POSITIVE', 'score': 0.9994192123413086}
# {'label': 'POSITIVE', 'score': 0.99899822473526}
# {'label': 'POSITIVE', 'score': 0.9992716908454895}
# {'label': 'POSITIVE', 'score': 0.9989266991615295}
# {'label': 'POSITIVE', 'score': 0.9985548853874207}
# {'label': 'POSITIVE', 'score': 0.9990756511688232}
# {'label': 'POSITIVE', 'score': 0.9996480941772461}
# {'label': 'POSITIVE', 'score': 0.9998834133148193}
# {'label': 'POSITIVE', 'score': 0.998871386051178}
# {'label': 'POSITIVE', 'score': 0.9996533393859863}
# {'label': 'POSITIVE', 'score': 0.9998828172683716}
# {'label': 'POSITIVE', 'score': 0.7199816107749939}
# {'label': 'POSITIVE', 'score': 0.9993094205856323}
# {'label': 'POSITIVE', 'score': 0.9985359907150269}
# {'label': 'POSITIVE', 'score': 0.9957540035247803}
# {'label': 'POSITIVE', 'score': 0.9097827076911926}
# {'label': 'POSITIVE', 'score': 0.9930552840232849}
# {'label': 'POSITIVE', 'score': 0.9989916682243347}
# {'label': 'POSITIVE', 'score': 0.9901394248008728}
# {'label': 'POSITIVE', 'score': 0.9943591952323914}
# {'label': 'POSITIVE', 'score': 0.8448774218559265}
# {'label': 'NEGATIVE', 'score': 0.9405766129493713}
# {'label': 'POSITIVE', 'score': 0.9956372380256653}
# {'label': 'NEGATIVE', 'score': 0.9112733006477356}
# {'label': 'POSITIVE', 'score': 0.9698801636695862}
# {'label': 'POSITIVE', 'score': 0.9988654851913452}
# {'label': 'POSITIVE', 'score': 0.9544273614883423}
# {'label': 'POSITIVE', 'score': 0.9996052384376526}
# {'label': 'POSITIVE', 'score': 0.9984317421913147}
# {'label': 'POSITIVE', 'score': 0.9807227253913879}
# {'label': 'POSITIVE', 'score': 0.9997304081916809}
# {'label': 'POSITIVE', 'score': 0.9687839150428772}
# {'label': 'POSITIVE', 'score': 0.9997068047523499}
# {'label': 'POSITIVE', 'score': 0.9997256398200989}
# {'label': 'POSITIVE', 'score': 0.9812368750572205}
# {'label': 'POSITIVE', 'score': 0.808252215385437}
# {'label': 'POSITIVE', 'score': 0.9962713718414307}
# {'label': 'NEGATIVE', 'score': 0.994296133518219}
# {'label': 'POSITIVE', 'score': 0.9989559650421143}
# {'label': 'POSITIVE', 'score': 0.9991958737373352}
# {'label': 'POSITIVE', 'score': 0.9987336993217468}
# {'label': 'POSITIVE', 'score': 0.6246588230133057}
# {'label': 'NEGATIVE', 'score': 0.9537820816040039}
# {'label': 'POSITIVE', 'score': 0.9925515651702881}
# {'label': 'NEGATIVE', 'score': 0.9980935454368591}
# {'label': 'POSITIVE', 'score': 0.9213718771934509}
# {'label': 'POSITIVE', 'score': 0.9971829652786255}
# {'label': 'POSITIVE', 'score': 0.9970076680183411}
# {'label': 'POSITIVE', 'score': 0.9990552067756653}
# {'label': 'POSITIVE', 'score': 0.9925766587257385}
# {'label': 'POSITIVE', 'score': 0.9996121525764465}
# {'label': 'POSITIVE', 'score': 0.9990954399108887}
# {'label': 'POSITIVE', 'score': 0.9998083710670471}
# {'label': 'POSITIVE', 'score': 0.9997885823249817}
# {'label': 'POSITIVE', 'score': 0.9982724189758301}
# {'label': 'POSITIVE', 'score': 0.9998107552528381}
# {'label': 'POSITIVE', 'score': 0.9994480013847351}
# {'label': 'POSITIVE', 'score': 0.9998766183853149}
# {'label': 'POSITIVE', 'score': 0.999854564666748}
# {'label': 'POSITIVE', 'score': 0.964236319065094}
# {'label': 'NEGATIVE', 'score': 0.8002082705497742}
# {'label': 'POSITIVE', 'score': 0.99908447265625}
# {'label': 'POSITIVE', 'score': 0.9781129956245422}
# {'label': 'POSITIVE', 'score': 0.9862809181213379}
# {'label': 'POSITIVE', 'score': 0.998173713684082}
# {'label': 'POSITIVE', 'score': 0.9790791273117065}
# {'label': 'POSITIVE', 'score': 0.5578591823577881}
# {'label': 'POSITIVE', 'score': 0.9990563988685608}
# {'label': 'POSITIVE', 'score': 0.9935573935508728}
# {'label': 'POSITIVE', 'score': 0.9993029832839966}
# {'label': 'NEGATIVE', 'score': 0.9804453253746033}
# {'label': 'POSITIVE', 'score': 0.9501070380210876}
# {'label': 'NEGATIVE', 'score': 0.9236350655555725}
# {'label': 'POSITIVE', 'score': 0.9901286959648132}
# {'label': 'POSITIVE', 'score': 0.9923186302185059}
# {'label': 'POSITIVE', 'score': 0.9994220733642578}
# {'label': 'NEGATIVE', 'score': 0.9920998215675354}
# {'label': 'NEGATIVE', 'score': 0.7715548276901245}
# {'label': 'POSITIVE', 'score': 0.9991471767425537}
# {'label': 'NEGATIVE', 'score': 0.9890882968902588}
# {'label': 'POSITIVE', 'score': 0.9997164607048035}
# {'label': 'POSITIVE', 'score': 0.9991849064826965}
# {'label': 'POSITIVE', 'score': 0.9968468546867371}
# {'label': 'NEGATIVE', 'score': 0.9533494114875793}
# {'label': 'POSITIVE', 'score': 0.9885650277137756}
# {'label': 'POSITIVE', 'score': 0.9991563558578491}
# {'label': 'POSITIVE', 'score': 0.9933713674545288}
# {'label': 'NEGATIVE', 'score': 0.5957738161087036}
# {'label': 'POSITIVE', 'score': 0.9079353213310242}
# {'label': 'NEGATIVE', 'score': 0.6949529051780701}
# {'label': 'POSITIVE', 'score': 0.6513784527778625}
# {'label': 'POSITIVE', 'score': 0.9991488456726074}
# {'label': 'POSITIVE', 'score': 0.9860390424728394}
# {'label': 'NEGATIVE', 'score': 0.5229575037956238}
# {'label': 'POSITIVE', 'score': 0.9886477589607239}
# {'label': 'POSITIVE', 'score': 0.9928687214851379}
# {'label': 'POSITIVE', 'score': 0.9996232986450195}
# {'label': 'POSITIVE', 'score': 0.9903844594955444}
# {'label': 'NEGATIVE', 'score': 0.7915019989013672}
# {'label': 'POSITIVE', 'score': 0.998322069644928}
# {'label': 'NEGATIVE', 'score': 0.9680420160293579}
# {'label': 'POSITIVE', 'score': 0.9594084620475769}
# {'label': 'POSITIVE', 'score': 0.999816358089447}
# {'label': 'POSITIVE', 'score': 0.9979275465011597}
# {'label': 'POSITIVE', 'score': 0.9980528354644775}
# {'label': 'POSITIVE', 'score': 0.9998511075973511}
# {'label': 'POSITIVE', 'score': 0.997957706451416}
# {'label': 'POSITIVE', 'score': 0.9934535026550293}
# {'label': 'POSITIVE', 'score': 0.9997310042381287}
# {'label': 'POSITIVE', 'score': 0.9998791217803955}
# {'label': 'NEGATIVE', 'score': 0.9966953992843628}
# {'label': 'POSITIVE', 'score': 0.6777079701423645}
# {'label': 'POSITIVE', 'score': 0.9996570348739624}
# {'label': 'NEGATIVE', 'score': 0.9969577789306641}
# {'label': 'POSITIVE', 'score': 0.9992449283599854}

# %%
## Writing Model Outputs to csv 

# import csv

# keys = results[0].keys()

# with open('results.csv', 'w', newline='') as output_file:
#     dict_writer = csv.DictWriter(output_file, keys)
#     dict_writer.writeheader()
#     dict_writer.writerows(results)

# %%
df = pd.DataFrame(results)
df["actual_label"] = labels
# df["actual_label"] = ['NEGATIVE' if x == 0 else "POSITIVE" for x in labels ]

df["label"] = [0 if x == "NEGATIVE" else 1 for x in df["label"] ]

# %%
# print(df["label"].value_counts())
# print(df["actual_label"].value_counts())
df
# Out:
#        label     score  actual_label
# 0          0  0.992256             0
# 1          0  0.999306             0
# 2          0  0.654144             0
# 3          0  0.950140             0
# 4          0  0.996621             0
# ...      ...       ...           ...
# 24995      0  0.996695             1
# 24996      1  0.677708             1
# 24997      1  0.999657             1
# 24998      0  0.996958             1
# 24999      1  0.999245             1
#
# [25000 rows x 3 columns]

# %%
### Evaluating Model Performance Metrocs 

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy Score:", round(accuracy_score(df["actual_label"], df["label"]),2))  # ratio of correctly predicted instances to the total instances in the dataset ((TP + TN) / (TP + TN + FP + FN))
print("Precision Score:", round(precision_score(df["actual_label"], df["label"]),2)) #  how many of the predicted positive instances are actually positive ( TP / (TP + FP))
print("Recall Score:", round(recall_score(df["actual_label"], df["label"]),2)) # proportion of actual positive instances that were correctly predicted (TP / (TP + FN))
print("F1 Score:", round(f1_score(df["actual_label"], df["label"]),2)) # the harmonic mean of precision and recall (2 * (Precision * Recall) / (Precision + Recall))
# Out:
# Accuracy Score: 0.84
# Precision Score: 0.9
# Recall Score: 0.77
# F1 Score: 0.83

# %%
# # Store the model we want to use
# MODEL_NAME = "bert-base-cased"

# # We need to create the model and tokenizer
# model = AutoModel.from_pretrained(MODEL_NAME)
# tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# # Testing that the model and tokenizer work as intended 
# tokens = tokenizer.tokenize("This is an input example")
# print("Tokens: {}".format(tokens))


# training_args = TrainingArguments("test-trainer")

# trainer = Trainer(
#     model,
#     training_args,
#     train_dataset = tokenized_datasets["train"]

# )
